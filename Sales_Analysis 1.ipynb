# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanka-max/JanuaryClass/blob/main/Sales_Analysis%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sales_data = pd.read_csv("https://raw.githubusercontent.com/Kanka-max/ADS_REV_code/main/08%20Lesson%20Sales%20Analysis/all_data.csv")
sales_data.head(10)
# Out:
#   Order ID  ...                        Purchase Address
# 0   176558  ...            917 1st St, Dallas, TX 75001
# 1      NaN  ...                                     NaN
# 2   176559  ...       682 Chestnut St, Boston, MA 02215
# 3   176560  ...    669 Spruce St, Los Angeles, CA 90001
# 4   176560  ...    669 Spruce St, Los Angeles, CA 90001
# 5   176561  ...       333 8th St, Los Angeles, CA 90001
# 6   176562  ...  381 Wilson St, San Francisco, CA 94016
# 7   176563  ...        668 Center St, Seattle, WA 98101
# 8   176564  ...         790 Ridge St, Atlanta, GA 30301
# 9   176565  ...  915 Willow St, San Francisco, CA 94016
#
# [10 rows x 6 columns]

# %%
import os


path = os.getcwd()
dir_list = os.listdir(path)
print(dir_list)

# %%
#empty data frame that will contain 12 month data AFTERWARD 

all_months_data= pd.DataFrame()

files =[file for file in os.listdir('./Sales_Data')]

for file in files:
    
    df=pd.read_csv("./Sales_Data/"+file)
    # Concatenating multiple csvs together to create a new DataFrame (pd.concat) 
    all_months_data=pd.concat([all_months_data, df])

all_months_data.head()

# %% [markdown]
# In this section we are goin to to analyze and answer business questions about 12 months worth of sales data. The data contains hundreds of thousands of
#
# electronics store purchases broken down by month, product type, cost, purchase address, etc.
#
# In this section we explore 5 high level business questions related to our data:
#
#     What was the best month for sales? How much was earned that month?
#     What city sold the most product?
#     What time should we display advertisemens to maximize the likelihood of customer’s buying product?
#     What products are most often sold together?
#     What product sold the most? Why do you think it sold the most?

# %%
sales_data.head(10)
# Out:
#   Order ID  ...                        Purchase Address
# 0   176558  ...            917 1st St, Dallas, TX 75001
# 1      NaN  ...                                     NaN
# 2   176559  ...       682 Chestnut St, Boston, MA 02215
# 3   176560  ...    669 Spruce St, Los Angeles, CA 90001
# 4   176560  ...    669 Spruce St, Los Angeles, CA 90001
# 5   176561  ...       333 8th St, Los Angeles, CA 90001
# 6   176562  ...  381 Wilson St, San Francisco, CA 94016
# 7   176563  ...        668 Center St, Seattle, WA 98101
# 8   176564  ...         790 Ridge St, Atlanta, GA 30301
# 9   176565  ...  915 Willow St, San Francisco, CA 94016
#
# [10 rows x 6 columns]

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
sales_data.shape
# Out:
# (186850, 6)

# %%
sales_data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
sales_data = sales_data.dropna(how="all")

# %%
temp_df = sales_data[sales_data["Order Date"].str[0:2]== "Or"]
temp_df.head()
# Out:
#       Order ID  Product  ...  Order Date  Purchase Address
# 519   Order ID  Product  ...  Order Date  Purchase Address
# 1149  Order ID  Product  ...  Order Date  Purchase Address
# 1155  Order ID  Product  ...  Order Date  Purchase Address
# 2878  Order ID  Product  ...  Order Date  Purchase Address
# 2893  Order ID  Product  ...  Order Date  Purchase Address
#
# [5 rows x 6 columns]

# %%
temp_df = sales_data[sales_data["Order Date"].str[0:2]!= "Or"]
temp_df
# Out:
#        Order ID  ...                         Purchase Address
# 0        176558  ...             917 1st St, Dallas, TX 75001
# 2        176559  ...        682 Chestnut St, Boston, MA 02215
# 3        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 4        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 5        176561  ...        333 8th St, Los Angeles, CA 90001
# ...         ...  ...                                      ...
# 186845   259353  ...   840 Highland St, Los Angeles, CA 90001
# 186846   259354  ...  216 Dogwood St, San Francisco, CA 94016
# 186847   259355  ...     220 12th St, San Francisco, CA 94016
# 186848   259356  ...   511 Forest St, San Francisco, CA 94016
# 186849   259357  ...   250 Meadow St, San Francisco, CA 94016
#
# [185950 rows x 6 columns]

# %%
temp_df["Quantity Ordered"] = pd.to_numeric(temp_df["Quantity Ordered"])
temp_df["Price Each"] = pd.to_numeric(temp_df["Price Each"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
temp_df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.9+ MB

# %%
# Feature Engineering
## Add Month Column


sales_data = temp_df.copy()
sales_data
# Out:
#        Order ID  ...                         Purchase Address
# 0        176558  ...             917 1st St, Dallas, TX 75001
# 2        176559  ...        682 Chestnut St, Boston, MA 02215
# 3        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 4        176560  ...     669 Spruce St, Los Angeles, CA 90001
# 5        176561  ...        333 8th St, Los Angeles, CA 90001
# ...         ...  ...                                      ...
# 186845   259353  ...   840 Highland St, Los Angeles, CA 90001
# 186846   259354  ...  216 Dogwood St, San Francisco, CA 94016
# 186847   259355  ...     220 12th St, San Francisco, CA 94016
# 186848   259356  ...   511 Forest St, San Francisco, CA 94016
# 186849   259357  ...   250 Meadow St, San Francisco, CA 94016
#
# [185950 rows x 6 columns]

# %%
sales_data.isna()
# Out:
#         Order ID  Product  ...  Order Date  Purchase Address
# 0          False    False  ...       False             False
# 2          False    False  ...       False             False
# 3          False    False  ...       False             False
# 4          False    False  ...       False             False
# 5          False    False  ...       False             False
# ...          ...      ...  ...         ...               ...
# 186845     False    False  ...       False             False
# 186846     False    False  ...       False             False
# 186847     False    False  ...       False             False
# 186848     False    False  ...       False             False
# 186849     False    False  ...       False             False
#
# [185950 rows x 6 columns]

# %%
sales_data["Month"] = sales_data["Order Date"].str[0:2]

sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 11.3+ MB

# %%
sales_data["Month"] = sales_data["Month"].astype("int32")

sales_data.head(3)
# Out:
#   Order ID  ... Month
# 0   176558  ...     4
# 2   176559  ...     4
# 3   176560  ...     4
#
# [3 rows x 7 columns]

# %%
#Sales Column
## Quantity Ordered // Price Each

sales_data["Sales"] = sales_data["Quantity Ordered"] * sales_data["Price Each"]
sales_data.head(3)
# Out:
#   Order ID                     Product  ...  Month   Sales
# 0   176558        USB-C Charging Cable  ...      4   23.90
# 2   176559  Bose SoundSport Headphones  ...      4   99.99
# 3   176560                Google Phone  ...      4  600.00
#
# [3 rows x 8 columns]

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
#  7   Sales             185950 non-null  float64
# dtypes: float64(2), int32(1), int64(1), object(4)
# memory usage: 12.1+ MB

# %%
#What was the best month for sales? HOw much was earned that month

sales_data.Sales.sum()
# Out:
# 34492035.97

# %%
#groupby

best_month_for_sales = sales_data.groupby("Month").sum().reset_index()
best_month_for_sales
# Out:
#     Month  Quantity Ordered  Price Each       Sales
# 0       1             10903  1811768.38  1822256.73
# 1       2             13449  2188884.72  2202022.42
# 2       3             17005  2791207.83  2807100.38
# 3       4             20558  3367671.02  3390670.24
# 4       5             18667  3135125.13  3152606.75
# 5       6             15253  2562025.61  2577802.26
# 6       7             16072  2632539.56  2647775.76
# 7       8             13448  2230345.42  2244467.88
# 8       9             13109  2084992.09  2097560.13
# 9      10             22703  3715554.83  3736726.88
# 10     11             19798  3180600.68  3199603.20
# 11     12             28114  4588415.41  4613443.34

# %%
best_month_for_sales = sales_data.groupby(["Month"])["Sales"].sum()
best_month_for_sales
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: Sales, dtype: float64

# %%
# Matplotlib chart

months = range(1,13)
plt.bar(months, best_month_for_sales.Sales)
plt.xticks(months)

#label the chart
plt.xlabel("Month Number")
plt.ylabel("Sales in USD")

#render the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-4e5625d0c441> in <module>()
#       2
#       3 months = range(1,13)
# ----> 4 plt.bar(months, best_month_for_sales.Sales)
#       5 plt.xticks(months)
#       6
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'Sales'

# %%
sns.barplot(data= best_month_for_sales, x = best_month_for_sales.Month, y = best_month_for_sales.Sales)
#best_month_for_sales.columns

# %%
sns.stripplot(data= best_month_for_sales, x = best_month_for_sales.Month, y = best_month_for_sales.Sales)

# %%
# Which city sold the most product?
sales_data
# Out:
#        Order ID                     Product  ...  Month   Sales
# 0        176558        USB-C Charging Cable  ...      4   23.90
# 2        176559  Bose SoundSport Headphones  ...      4   99.99
# 3        176560                Google Phone  ...      4  600.00
# 4        176560            Wired Headphones  ...      4   11.99
# 5        176561            Wired Headphones  ...      4   11.99
# ...         ...                         ...  ...    ...     ...
# 186845   259353      AAA Batteries (4-pack)  ...      9    8.97
# 186846   259354                      iPhone  ...      9  700.00
# 186847   259355                      iPhone  ...      9  700.00
# 186848   259356      34in Ultrawide Monitor  ...      9  379.99
# 186849   259357        USB-C Charging Cable  ...      9   11.95
#
# [185950 rows x 8 columns]

# %%
# WHich city sold the most product?

# split(delimiter), strip(delimiter)

# lambda fx - one condition, one expression

def get_city(address):
  return address.split(",")[1].strip(" ")

def get_state(address):
  return address.split(",")[2].split(" ")[1]

sales_data["City"] = sales_data["Purchase Address"].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
sales_data.head()
# Out:
#   Order ID                     Product  ...   Sales              City
# 0   176558        USB-C Charging Cable  ...   23.90       Dallas (TX)
# 2   176559  Bose SoundSport Headphones  ...   99.99       Boston (MA)
# 3   176560                Google Phone  ...  600.00  Los Angeles (CA)
# 4   176560            Wired Headphones  ...   11.99  Los Angeles (CA)
# 5   176561            Wired Headphones  ...   11.99  Los Angeles (CA)
#
# [5 rows x 9 columns]

# %%
city_sales = sales_data.groupby(["City"]).sum()
city_sales
# Out:
#                     Quantity Ordered  Price Each   Month       Sales
# City
# Atlanta (GA)                   16602  2779908.20  104794  2795498.58
# Austin (TX)                    11153  1809873.61   69829  1819581.75
# Boston (MA)                    22528  3637409.77  141112  3661642.01
# Dallas (TX)                    16730  2752627.82  104620  2767975.40
# Los Angeles (CA)               33289  5421435.23  208325  5452570.80
# New York City (NY)             27932  4635370.83  175741  4664317.43
# Portland (ME)                   2750   447189.25   17144   449758.27
# Portland (OR)                  11303  1860558.22   70621  1870732.34
# San Francisco (CA)             50239  8211461.74  315520  8262203.91
# Seattle (WA)                   16553  2733296.01  104941  2747755.48

# %%
city_sales_spec = sales_data.groupby(["City"])["Sales"].sum().reset_index()

# %%
city_sales_spec
# Out:
#                  City       Sales
# 0        Atlanta (GA)  2795498.58
# 1         Austin (TX)  1819581.75
# 2         Boston (MA)  3661642.01
# 3         Dallas (TX)  2767975.40
# 4    Los Angeles (CA)  5452570.80
# 5  New York City (NY)  4664317.43
# 6       Portland (ME)   449758.27
# 7       Portland (OR)  1870732.34
# 8  San Francisco (CA)  8262203.91
# 9        Seattle (WA)  2747755.48

# %%
keys = [city for city, df in sales_data.groupby(["City"])]


plt.bar(keys, sales_data.groupby(["City"]).sum()["Sales"])

# labeling of the axes

plt.xlabel("Cities")
plt.ylabel("Sales in USD ($)")
plt.xticks(keys, rotation="vertical", size = 8)
plt.show()

# %%
city_sales_spec
# Out:
#                  City       Sales
# 0        Atlanta (GA)  2795498.58
# 1         Austin (TX)  1819581.75
# 2         Boston (MA)  3661642.01
# 3         Dallas (TX)  2767975.40
# 4    Los Angeles (CA)  5452570.80
# 5  New York City (NY)  4664317.43
# 6       Portland (ME)   449758.27
# 7       Portland (OR)  1870732.34
# 8  San Francisco (CA)  8262203.91
# 9        Seattle (WA)  2747755.48

# %%
city_sales_spec.columns
# Out:
# Index(['City', 'Sales'], dtype='object')

# %%
plt.rcParams["figure.figsize"] = (10, 12)
sns.barplot(data=city_sales_spec, x = "Sales", y = "City", orient = "h")

# increase the figure size
#change the xticks rotation
# change the figures' orientation

# %%
# What time should we display advertisements to maximize the likelihood of customer"s buying product
# Order Date - hour, minute

#day, month, year, hour, minute - 

sales_data["Hour"] = pd.to_datetime(sales_data["Order Date"]).dt.hour

# minute column

sales_data["Minute"] = pd.to_datetime(sales_data["Order Date"]).dt.minute

#add frequency column

sales_data["Count"] = 1

sales_data.head(6)
# Out:
#   Order ID                     Product  Quantity Ordered  ...  Hour Minute Count
# 0   176558        USB-C Charging Cable                 2  ...     8     46     1
# 2   176559  Bose SoundSport Headphones                 1  ...    22     30     1
# 3   176560                Google Phone                 1  ...    14     38     1
# 4   176560            Wired Headphones                 1  ...    14     38     1
# 5   176561            Wired Headphones                 1  ...     9     27     1
# 6   176562        USB-C Charging Cable                 1  ...    13      3     1
#
# [6 rows x 12 columns]

# %%
keys = []
for pair, df in sales_data.groupby(["Hour"]):
     keys.append(pair)

# %%
plt.rcParams["figure.figsize"] = (6, 6)
keys = [pair for pair, df in sales_data.groupby(["Hour"])]

plt.plot(keys, sales_data.groupby(["Hour"]).count()["Count"])
plt.xticks(keys)
plt.grid()
plt.show()

# %%
seaborn_alt = sales_data.groupby(["Hour"]).count()["Count"].reset_index()
seaborn_alt.head()
# Out:
#    Hour  Count
# 0     0   3910
# 1     1   2350
# 2     2   1243
# 3     3    831
# 4     4    854

# %%
plt.rcParams["figure.figsize"] = (14, 10)
sns.set_style("dark")
sns.axes_style("white")

ax = sns.lineplot(data=seaborn_alt, x = seaborn_alt.Hour, y = seaborn_alt.Count, 
             err_style = "band", markers = True, color = "DarkMagenta")
ax.set_title("AT WHAT TIME SHOULD WE DISPLAY ADVERTS?")
ax.set_ylabel('Customer Purchases (In Sales)')
ax.set_xlabel('Time Of Customer Purchase (24 HRS)')
# Out:
# Text(0.5, 0, 'Time Of Customer Purchase (24 HRS)')

# %%
# What products are most often sold together

sales_data
# Out:
#        Order ID                     Product  ...  Minute  Count
# 0        176558        USB-C Charging Cable  ...      46      1
# 2        176559  Bose SoundSport Headphones  ...      30      1
# 3        176560                Google Phone  ...      38      1
# 4        176560            Wired Headphones  ...      38      1
# 5        176561            Wired Headphones  ...      27      1
# ...         ...                         ...  ...     ...    ...
# 186845   259353      AAA Batteries (4-pack)  ...      56      1
# 186846   259354                      iPhone  ...       0      1
# 186847   259355                      iPhone  ...      39      1
# 186848   259356      34in Ultrawide Monitor  ...      30      1
# 186849   259357        USB-C Charging Cable  ...      18      1
#
# [185950 rows x 12 columns]

# %%
df = sales_data[sales_data["Order ID"].duplicated(keep=False)]
df.head()
# Out:
#    Order ID                     Product  Quantity Ordered  ...  Hour Minute Count
# 3    176560                Google Phone                 1  ...    14     38     1
# 4    176560            Wired Headphones                 1  ...    14     38     1
# 18   176574                Google Phone                 1  ...    19     42     1
# 19   176574        USB-C Charging Cable                 1  ...    19     42     1
# 30   176585  Bose SoundSport Headphones                 1  ...    11     31     1
#
# [5 rows x 12 columns]

# %%
# group the product with the same order id
#  Groupby the "Order ID" and "Product" columns
#  call transform which will return the data aligned to the origina df
#  apply lambda 

df["Grouped"] = df.groupby("Order ID")["Product"].transform(lambda x:",".join(x))
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Order ID  ...                                            Grouped
# 3    176560  ...                      Google Phone,Wired Headphones
# 4    176560  ...                      Google Phone,Wired Headphones
# 18   176574  ...                  Google Phone,USB-C Charging Cable
# 19   176574  ...                  Google Phone,USB-C Charging Cable
# 30   176585  ...  Bose SoundSport Headphones,Bose SoundSport Hea...
#
# [5 rows x 13 columns]

# %%
df = df[["Order ID", "Grouped"]].drop_duplicates()

# %%
df
# Out:
#        Order ID                                            Grouped
# 3        176560                      Google Phone,Wired Headphones
# 18       176574                  Google Phone,USB-C Charging Cable
# 30       176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32       176586                AAA Batteries (4-pack),Google Phone
# 119      176672      Lightning Charging Cable,USB-C Charging Cable
# ...         ...                                                ...
# 186781   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 186783   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 186791   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803   259314            Wired Headphones,AAA Batteries (4-pack)
# 186841   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df["Grouped"]:
  row_list = row.split(",")
  count.update(Counter(combinations(row_list, 2)))

count.most_common(50)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92),
#  (('Lightning Charging Cable', 'Apple Airpods Headphones'), 81),
#  (('Vareebadd Phone', 'Bose SoundSport Headphones'), 80),
#  (('USB-C Charging Cable', 'Bose SoundSport Headphones'), 77),
#  (('Apple Airpods Headphones', 'Wired Headphones'), 69),
#  (('Lightning Charging Cable', 'USB-C Charging Cable'), 58),
#  (('Lightning Charging Cable', 'AA Batteries (4-pack)'), 55),
#  (('Lightning Charging Cable', 'Lightning Charging Cable'), 54),
# ...
